# %%
import os
import logging
import germline_cnv_evaluation as cnv_eval

logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
                    datefmt='%m-%d %H:%M')

genome_strip_vcf_file = '/Volumes/dsde_working/mehrtash/gCNV_theano_eval_new/GPC2-WES/gs/gpc2_gs_callset_v3.vcf'
gs_call_set_dict, gs_included_loci = cnv_eval.load_genome_strip_vcf_file(genome_strip_vcf_file)
# Out:
# 04-05 12:52 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 0...
# 04-05 12:52 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 500...
# 04-05 12:53 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 1000...
# 04-05 12:53 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 1500...
# 04-05 12:54 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 2000...
# 04-05 12:54 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 2500...
# 04-05 12:54 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 3000...
# 04-05 12:55 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 3500...
# 04-05 12:55 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 4000...
# 04-05 12:55 germline_cnv_evaluation.io_genome_strip_vcf INFO     Reading record number 4500...
# ...

# %%
cnv_eval.GenericCNVCallSet.to_pickle(
    '/Volumes/dsde_working/mehrtash/gCNV_theano_eval_new/GPC2-WES/gs/\
gpc2_gs_callset_v3_CNV_eval_suite_ver__{0}__.pkl'.format(cnv_eval.__version__),
    gs_call_set_dict, gs_included_loci)
